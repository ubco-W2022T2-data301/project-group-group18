# %%
import pandas as pd
data = pd.read_csv("1.csv")
data
# Out:
# /var/folders/yd/8dvmmvhs6h17pc2r3tybl1040000gn/T/ipykernel_10797/3944635755.py:2: DtypeWarning: Columns (12,13,14,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("1.csv")
#        iso_code                      region_group          income_group  \
# 0           AFG         Central and Southern Asia  Low income countries
# 1           AFG         Central and Southern Asia  Low income countries
# 2           AFG         Central and Southern Asia  Low income countries
# 3           AFG         Central and Southern Asia  Low income countries
# 4           AFG         Central and Southern Asia  Low income countries
# ...         ...                               ...                   ...
# 212964      NaN  Northern Africa and Western Asia                   NaN
# 212965      NaN  Northern Africa and Western Asia                   NaN
# 212966      NaN  Northern Africa and Western Asia                   NaN
# ...
